# %% [markdown]
# # Train Models with SageMaker
# Ok! Now that we've spent a healthy amount of time formatting our data and making changes to it, let's train our first model on SageMaker.
#
# At a minimum, during a 3 day course, participants should be able to produce a single model. As a strectch goal they should be able to produce 2 or more models and compare them.

# %%
import pandas as pd
import sagemaker

# %%
data = pd.read_csv("../Data/fewer_labeled_rows_by_block.csv")

# %% [markdown]
# Because the dimensionality here is so high, it's wise to use a simple model. We'll start off with linear learner.

# %%
data.shape
# Out:
# (33063, 1512)

# %%
import boto3
from sagemaker import get_execution_role

from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')

# %%
import numpy as np

def create_a_train_set(data):
    ys = np.array(data["Target"])
        
    drop_list = ["Target", "Date", "Primary Type"]
    
    xs = np.array(data.drop(drop_list, axis=1))
    
    return [xs, ys]
    
train_set = create_a_train_set(data)

# %%
len(train_set[0][0])
# Out:
# 1509

# %%
train_records = multiclass_estimator.record_set(train_features, train_labels, channel='train')
val_records = multiclass_estimator.record_set(val_features, val_labels, channel='validation')
test_records = multiclass_estimator.record_set(test_features, test_labels, channel='test')

# %%
sess = sagemaker.Session()
bucket = "sagemaker-chicago-data"

role = get_execution_role()

# %%
import os

prefix = "sagemaker"

key = "modeling-data"

boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)

print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-chicago-data/sagemaker/train/modeling-data

# %%
output_location = 's3://{}/{}/model_artifacts'.format(bucket, prefix)

print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://sagemaker-chicago-data/sagemaker/model_artifacts

# %%
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m4.4xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)

linear.set_hyperparameters(feature_dim=1509,
                           predictor_type='multiclass_classifier',
                           mini_batch_size=200,
                          num_classes = 6)

linear.fit({'train': s3_train_data})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2018-10-22-22-32-27-495
# 2018-10-22 22:32:27 Starting - Starting the training job...
# 2018-10-22 22:32:29 Starting - Launching requested ML instances......
# 2018-10-22 22:33:32 Starting - Preparing the instances for training......
# 2018-10-22 22:34:55 Downloading - Downloading input data
# 2018-10-22 22:34:55 Training - Downloading the training image.
# Docker entrypoint called with argument(s): train
# [10/22/2018 22:35:01 INFO 139848689157952] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/22/2018 22:35:01 INFO 139848689157952] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'1509', u'mini_batch_size': u'200', u'predictor_type': u'multiclass_classifier', u'num_classes': u'6'}
# [10/22/2018 22:35:01 INFO 139848689157952] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'1509', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'6', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/22/2018 22:35:01 WARNING 139848689157952] Loggers have already been setup.
# [10/22/2018 22:35:01 INFO 139848689157952] Using default worker.
# [10/22/2018 22:35:01 INFO 139848689157952] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [10/22/2018 22:35:01 INFO 139848689157952] Create Store: local
# [10/22/2018 22:35:02 INFO 139848689157952] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f30c7069510>
# [10/22/2018 22:35:02 INFO 139848689157952] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 6.76237106  0.01400143  0.02618785 ...,  0.01400143  0.02213494
#   0.00990099]
# <NDArray 1509 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [  8.33434830e+01   1.96078428e-04   6.86274434e-04 ...,   1.96078428e-04
#    4.90196166e-04   9.80392142e-05]
# <NDArray 1509 @cpu(0)>}
# [10/22/2018 22:35:02 INFO 139848689157952] nvidia-smi took: 0.0251920223236 secs to identify 0 gpus
# [10/22/2018 22:35:02 INFO 139848689157952] Number of GPUs being used: 0
"Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.977812}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.007015058899693417, "sum": 0.007015058899693417, "min": 0.007015058899693417}}, "EndTime": 1540247722.977858, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.977849}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0, "sum": 0.0, "min": 0.0}}, "EndTime": 1540247722.977897, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.977888}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.005775832031712388, "sum": 0.005775832031712388, "min": 0.005775832031712388}}, "EndTime": 1540247722.97796, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.977946}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0009754078781062907, "sum": 0.0009754078781062907, "min": 0.0009754078781062907}}, "EndTime": 1540247722.978021, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.978009}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0002974957822483372, "sum": 0.0002974957822483372, "min": 0.0002974957822483372}}, "EndTime": 1540247722.97808, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.978069}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 2.4709467640301833e-06, "sum": 2.4709467640301833e-06, "min": 2.4709467640301833e-06}}, "EndTime": 1540247722.978115, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.978107}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 2.1535522319027221e-07, "sum": 2.1535522319027221e-07, "min": 2.1535522319027221e-07}}, "EndTime": 1540247722.978149, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247722.978141}
#
# [10/22/2018 22:35:22 INFO 139848689157952] #quality_metric: host=algo-1, epoch=2, train multiclass_cross_entropy_objective <loss>=5.18069671975e-05
# [10/22/2018 22:35:22 INFO 139848689157952] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=multiclass_cross_entropy_objective, value=0.0
# [10/22/2018 22:35:22 INFO 139848689157952] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 166, "sum": 166.0, "min": 166}, "Number of Batches Since Last Reset": {"count": 1, "max": 166, "sum": 166.0, "min": 166}, "Number of Records Since Last Reset": {"count": 1, "max": 33063, "sum": 33063.0, "min": 33063}, "Total Batches Seen": {"count": 1, "max": 550, "sum": 550.0, "min": 550}, "Total Records Seen": {"count": 1, "max": 109589, "sum": 109589.0, "min": 109589}, "Max Records Seen Between Resets": {"count": 1, "max": 33063, "sum": 33063.0, "min": 33063}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1540247722.978898, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1540247716.174443}
#
# [10/22/2018 22:35:22 INFO 139848689157952] #throughput_metric: host=algo-1, train throughput=4858.94892981 records/second
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 5.1867107380971766e-05, "sum": 5.1867107380971766e-05, "min": 5.1867107380971766e-05}}, "EndTime": 1540247729.77974, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.779677}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 7.808701202245147e-07, "sum": 7.808701202245147e-07, "min": 7.808701202245147e-07}}, "EndTime": 1540247729.779826, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.779811}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0, "sum": 0.0, "min": 0.0}}, "EndTime": 1540247729.779869, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.779859}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0009255074017031196, "sum": 0.0009255074017031196, "min": 0.0009255074017031196}}, "EndTime": 1540247729.779901, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.779893}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 7.698647699946763e-07, "sum": 7.698647699946763e-07, "min": 7.698647699946763e-07}}, "EndTime": 1540247729.779935, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.779927}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 3.777460602577776e-06, "sum": 3.777460602577776e-06, "min": 3.777460602577776e-06}}, "EndTime": 1540247729.779974, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.779965}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 2.32639241484335e-09, "sum": 2.32639241484335e-09, "min": 2.32639241484335e-09}}, "EndTime": 1540247729.780047, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.780029}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0035367562743750486, "sum": 0.0035367562743750486, "min": 0.0035367562743750486}}, "EndTime": 1540247729.780095, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.780085}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 7.904054695796787e-05, "sum": 7.904054695796787e-05, "min": 7.904054695796787e-05}}, "EndTime": 1540247729.780129, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.78012}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 7.83388369569593e-08, "sum": 7.83388369569593e-08, "min": 7.83388369569593e-08}}, "EndTime": 1540247729.78016, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1540247729.780153}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1
"Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.323762}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.4564210057759544e-06, "sum": 1.4564210057759544e-06, "min": 1.4564210057759544e-06}}, "EndTime": 1540247743.323847, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.32383}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0023980890544074954, "sum": 0.0023980890544074954, "min": 0.0023980890544074954}}, "EndTime": 1540247743.323916, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.323899}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0, "sum": 0.0, "min": 0.0}}, "EndTime": 1540247743.32398, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.323962}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0018855927331429539, "sum": 0.0018855927331429539, "min": 0.0018855927331429539}}, "EndTime": 1540247743.324019, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.32401}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.0004330236873391903, "sum": 0.0004330236873391903, "min": 0.0004330236873391903}}, "EndTime": 1540247743.324051, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.324043}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 8.197795426839907e-06, "sum": 8.197795426839907e-06, "min": 8.197795426839907e-06}}, "EndTime": 1540247743.324081, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.324074}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 7.612726789595785e-07, "sum": 7.612726789595785e-07, "min": 7.612726789595785e-07}}, "EndTime": 1540247743.324113, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.324106}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.788139525160659e-07, "sum": 1.788139525160659e-07, "min": 1.788139525160659e-07}}, "EndTime": 1540247743.324144, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247743.324136}
#
# [10/22/2018 22:35:43 INFO 139848689157952] #quality_metric: host=algo-1, epoch=5, train multiclass_cross_entropy_objective <loss>=5.1664276359e-05
# [10/22/2018 22:35:43 INFO 139848689157952] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=multiclass_cross_entropy_objective, value=0.0
# [10/22/2018 22:35:43 INFO 139848689157952] Early stop condition met. Stopping training.
# [10/22/2018 22:35:43 INFO 139848689157952] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 166, "sum": 166.0, "min": 166}, "Number of Batches Since Last Reset": {"count": 1, "max": 166, "sum": 166.0, "min": 166}, "Number of Records Since Last Reset": {"count": 1, "max": 33063, "sum": 33063.0, "min": 33063}, "Total Batches Seen": {"count": 1, "max": 1048, "sum": 1048.0, "min": 1048}, "Total Records Seen": {"count": 1, "max": 208778, "sum": 208778.0, "min": 208778}, "Max Records Seen Between Resets": {"count": 1, "max": 33063, "sum": 33063.0, "min": 33063}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1540247743.32502, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1540247736.541436}
#
# [10/22/2018 22:35:43 INFO 139848689157952] #throughput_metric: host=algo-1, train throughput=4873.87449949 records/second
# [10/22/2018 22:35:43 WARNING 139848689157952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/22/2018 22:35:43 WARNING 139848689157952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('multiclass_cross_entropy_objective', 0.0)
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('multiclass_accuracy', 1.0)
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('dcg', 1.0)
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('macro_recall', nan)
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('macro_precision', nan)
# [10/22/2018 22:35:44 INFO 139848689157952] #train_score (algo-1) : ('macro_f_1.000', nan)
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train multiclass_cross_entropy_objective <loss>=0.0
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train multiclass_accuracy <score>=1.0
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train multiclass_top_k_accuracy_3 <score>=1.0
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train dcg <score>=1.0
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train macro_recall <score>=nan
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train macro_precision <score>=nan
# [10/22/2018 22:35:44 INFO 139848689157952] #quality_metric: host=algo-1, train macro_f_1.000 <score>=nan
# [10/22/2018 22:35:44 INFO 139848689157952] Best model found for hyperparameters: {"lr_scheduler_step": 38, "wd": 0.002288549598988364, "optimizer": "rmsprop", "lr_scheduler_factor": 0.9718316553176904, "l1": 0.015379086140622243, "learning_rate": 0.04894414201957118, "lr_scheduler_minimum_lr": 5.0968542639990265e-05}
# [10/22/2018 22:35:44 INFO 139848689157952] Saved checkpoint to "/tmp/tmpMIHyq1/mx-mod-0000.params"
# [10/22/2018 22:35:44 INFO 139848689157952] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 42943.26090812683, "sum": 42943.26090812683, "min": 42943.26090812683}, "finalize.time": {"count": 1, "max": 1181.3349723815918, "sum": 1181.3349723815918, "min": 1181.3349723815918}, "initialize.time": {"count": 1, "max": 881.9930553436279, "sum": 881.9930553436279, "min": 881.9930553436279}, "check_early_stopping.time": {"count": 6, "max": 0.9660720825195312, "sum": 2.5224685668945312, "min": 0.1461505889892578}, "setuptime": {"count": 1, "max": 15.368938446044922, "sum": 15.368938446044922, "min": 15.368938446044922}, "update.time": {"count": 6, "max": 6810.8110427856445, "sum": 40766.552209854126, "min": 6758.74400138855}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1540247744.516393, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1540247701.657109}
# Billable seconds: 77

# %%
from sklearn.model_selection import train_test_split

# %%
import sagemaker

sess = sagemaker.Session()

endpoint_name = "chicago-predictor"

predictor = sagemaker.predictor.RealTimePredictor(endpoint_name, sess)

# %% [markdown]
# # Now that we have our predictor, let's evaluate the model

# %%
def create_train_test_set(train_set):
        
    np.random.seed(0)

    train_features, test_features, train_labels, test_labels = train_test_split(
    train_set[0], train_set[1], test_size=0.2)
    
    
    return train_features, test_features, train_labels, test_labels
    
train_xs, test_xs, train_ys, test_ys = create_train_test_set(train_set)

# %%
def evaluate_metrics(predictor, test_features, test_labels):
    """
    Evaluate a model on a test set using the given prediction endpoint. 
    Display classification metrics.
    This function was written by Zohar and others on the SageMaker blog
    """
    # split the test dataset into 100 batches and evaluate using prediction endpoint
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]

    # parse protobuf responses to extract predicted labels
#     extract_label = lambda x: x.label['predicted_label'].float32_tensor.values
#     test_preds = np.concatenate([np.array([extract_label(x) for x in batch]) for batch in prediction_batches])
#     test_preds = test_preds.reshape((-1,))
    
#     # calculate accuracy
#     accuracy = (test_preds == test_labels).sum() / test_labels.shape[0]
    
#     # calculate recall for each class
#     recall_per_class, classes = [], []
#     for target_label in np.unique(test_labels):
#         recall_numerator = np.logical_and(test_preds == target_label, test_labels == target_label).sum()
#         recall_denominator = (test_labels == target_label).sum()
#         recall_per_class.append(recall_numerator / recall_denominator)
#         classes.append(label_map[target_label])
#     recall = pd.DataFrame({'recall': recall_per_class, 'class_label': classes})
#     recall.sort_values('class_label', ascending=False, inplace=True)

#     # calculate confusion matrix
#     label_mapper = np.vectorize(lambda x: label_map[x])
#     confusion_matrix = pd.crosstab(label_mapper(test_labels), label_mapper(test_preds), 
#                                    rownames=['Actuals'], colnames=['Predictions'], normalize='index')

#     # display results
#     sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap="YlGnBu").set_title('Confusion Matrix')  
#     ax = recall.plot(kind='barh', x='class_label', y='recall', color='steelblue', title='Recall', legend=False)
#     ax.set_ylabel('')
#     print('Accuracy: {:.3f}'.format(accuracy))

# %%
evaluate_metrics(predictor, test_xs, test_ys)
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <ipython-input-18-ba5ab232bb94> in <module>()
# ----> 1 evaluate_metrics(predictor, test_xs, test_ys)
#
# <ipython-input-3-e45a8d36944a> in evaluate_metrics(predictor, test_features, test_labels)
#       4     """
#       5     # split the test dataset into 100 batches and evaluate using prediction endpoint
# ----> 6     prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
#       7
#       8     # parse protobuf responses to extract predicted labels
#
# <ipython-input-3-e45a8d36944a> in <listcomp>(.0)
#       4     """
#       5     # split the test dataset into 100 batches and evaluate using prediction endpoint
# ----> 6     prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
#       7
#       8     # parse protobuf responses to extract predicted labels
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data)
#      85             request_args['Accept'] = self.accept
#      86
# ---> 87         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#      88
#      89         response_body = response['Body']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     312                     "%s() only accepts keyword arguments." % py_operation_name)
#     313             # The "self" in this scope is referring to the BaseClient.
# --> 314             return self._make_api_call(operation_name, kwargs)
#     315
#     316         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     584         }
#     585         request_dict = self._convert_to_request_dict(
# --> 586             api_params, operation_model, context=request_context)
#     587
#     588         handler, event_response = self.meta.events.emit_until_response(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     619             api_params, operation_model, context)
#     620         request_dict = self._serializer.serialize_to_request(
# --> 621             api_params, operation_model)
#     622         prepare_request_dict(request_dict, endpoint_url=self._endpoint.host,
#     623                              user_agent=self._client_config.user_agent,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/validate.py in serialize_to_request(self, parameters, operation_model)
#     289                                                     operation_model.input_shape)
#     290             if report.has_errors():
# --> 291                 raise ParamValidationError(report=report.generate_report())
#     292         return self._serializer.serialize_to_request(parameters,
#     293                                                      operation_model)
#
# ParamValidationError: Parameter validation failed:
# Invalid type for parameter Body, value: [[50.          0.          0.         ...  0.          0.
#    0.        ]
#  [46.88888889  0.          0.         ...  0.          0.
#    0.        ]
#  [50.          0.          0.         ...  0.          0.
#    0.        ]
#  ...
#  [80.55555556  0.          0.         ...  0.          0.
#    0.        ]
#  [41.33333333  0.          0.         ...  0.          0.
#    0.        ]
#  [69.11111111  0.          0.         ...  0.          0.
#    0.        ]], type: <class 'numpy.ndarray'>, valid types: <class 'bytes'>, <class 'bytearray'>, file-like object

# %% [markdown]
# # Next, we'll run the model with balanced class weights, and observe the improvement in performance
